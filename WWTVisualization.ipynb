# %% [markdown]
# # WWT Data Visualization : Galactic Center data sets

# %% [markdown]
# ## imports

# %%
from wwt_data_formats import imageset, folder, place, write_xml_doc
from PIL import Image
from astropy import coordinates, units as u
import pyavm

# %%
import os

b1 = fits.open('AG-Laboca-Planck.49.5.fits')
b2 = fits.open('W51_90cm_CDBB.fits')[0]
b3 = fits.open('grs_13CO_max_30to90kms.fits')

hdr = fits.Header.fromtextfile('hdr4096.hdr')

b1d,_ = reproject.reproject_interp(b1, hdr)
b2d,_ = reproject.reproject_interp((b2.data, wcs.WCS(b2.header).celestial), hdr)
b3d,_ = reproject.reproject_interp(b3, hdr)


def linearize(x, xmin=None, xmax=None, truncate=True):
    if np.isscalar(x):
        return x
    else:
        if xmin is None:
            xmin = np.nanmin(x)
        if xmax is None:
            xmax = np.nanmax(x)
        if truncate:
            x = np.copy(x)
            x[x<xmin] = xmin
            x[x>xmax] = xmax
        return ((x-xmin)/(xmax-xmin))

def logscale(arr, logexp=3.0, toint=True, relinearize=True, **kwargs):
    linarr = linearize(arr, **kwargs)
    if logexp is None:
        logarr = linarr
    else:
        logarr = np.log10(linarr * 10**logexp + 1)
    if relinearize:
        return linearize(logarr)
    elif toint:
        lla = linearize(logarr)*255
        return lla.astype('uint8')
    else:
        return logarr

def expscale(arr, exp=2, toint=True, **kwargs):
    linarr = linearize(arr, **kwargs)
    if toint:
        lla = linearize(linarr**exp)*255
        return lla.astype('uint8')
    else:
        return linarr**exp


red = linearize(b2d, xmin=-0.05, xmax=0.2) * 0.75 + linearize(b2d, xmin=0.2, xmax=0.7)*0.25
#red = linearize(b2d, xmin=0.01, xmax=0.2)
green = (linearize(b3d, 0, 7))
blue = linearize(b1d,0,0.5) * 0.5 + logscale(b1d, xmin=0.5, xmax=50, toint=False)*0.5
#blue = logscale(b1d, xmin=0.10, xmax=10, toint=False)

rgb = np.array([red,green,blue]).T.swapaxes(0,1)
slices = slice(300,1300), slice(400,1600), slice(None) #[300:1300,400:1600]
rgb_crop = rgb[slices]

mywcs = wcs.WCS(hdr)[slices[:2]]
avm = pyavm.AVM.from_wcs(mywcs)

outfn = "RGB_90cm_CO_ATLASGAL.png"
im = PIL.Image.fromarray((rgb_crop*255).astype('uint8')[::-1,:])
im.save(outfn)
avm.embed(outfn, outfn)

pl.figure(1).clf()
pl.imshow(im)

pl.matplotlib.rc_file('pubfiguresrc')

pl.figure(2).clf()
FF = aplpy.FITSFigure(outfn, figure=pl.figure(2))
FF.show_rgb(outfn)
FF.set_tick_labels_format('dd.d','dd.d')
FF.save('aplpy_'+outfn)

FF.add_scalebar(((10*u.pc)/(5.1*u.kpc)*u.radian).to(u.deg).value)
FF.scalebar.set_label("10 pc")
FF.scalebar.set_font_size(18)
FF.scalebar.set_font_weight('bold')
FF.scalebar.set_color('w')
FF.scalebar.set_linewidth(3)
FF.save('aplpy_scalebar_'+outfn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import os
# ----> 3 b1 = fits.open('AG-Laboca-Planck.49.5.fits')
#       4 b2 = fits.open('W51_90cm_CDBB.fits')[0]
#       5 b3 = fits.open('grs_13CO_max_30to90kms.fits')
#
# NameError: name 'fits' is not defined

# %%
basepath = '/orange/adamginsburg/web/public/jwst/brick_2221/'

# %%
fld = folder.Folder()
fld.browseable = True
fld.group = 'Explorer'
fld.name = 'The Brick'
fld.searchable = True
fld.thumbnail = 'http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter.png'
fld.type = 'SKY'
fld.children = []

for name, imgname in {"Starry Brick F405+F466": 'BrickJWST_merged_longwave_narrowband_withstars.png',
                      "Starless Brick F405+466": 'BrickJWST_merged_longwave_narrowband_lighter.png',
                      "Brick: JWST and ALMA": 'BrickALMAJWST_WhiteHaze.png',
                      "Brick: Spitzer": "BrickSpitzer_RGB_I421.png",
                      "Cloud C: F405N+F466N": "/orange/adamginsburg/jwst/cloudc/images/cloudcJWST_merged_R-F466N_B-F405N_rotated.png",
                        }.items():
    
    if 'cloudc' in imgname:
        cloudc = 'cloudc/'
        imfn = imgname
        imgname = os.path.basename(imgname)
    else:
        cloudc = ''
        imfn = f'{basepath}/{imgname}'
    img = Image.open(imfn)
    img.thumbnail((100, 100))
    img.save(imfn.replace(".png", "_thumbnail.png"))
    img = Image.open(imfn)
    
    avm = pyavm.AVM.from_image(imfn)
    ww = avm.to_wcs()
    height, width, _ = np.array(img).shape
    
    pl = place.Place()
    pl.name = name
    pl.thumbnail = f'http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/{cloudc}{imgname.replace(".png", "_thumbnail.png")}'
    pl.constellation = 'SAGITTARIUS'
    pl.data_set_type = 'SKY'
    pl.opacity = 100
    pl.zoom_level = 2
    
    imgset = imageset.ImageSet()
    imgset.set_position_from_wcs(ww.to_header(), width=width, height=height, place=pl, fov_factor=2.5)
    imgset.url = f'http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/{cloudc}{imgname}'
    imgset.thumbnail_url = f'http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/{cloudc}{imgname.replace(".png", "_thumbnail.png")}'
    imgset.bottoms_up = False
    imgset.rotation_deg = 90
    imgset.band_pass = "INFRARED"
    imgset.offset_x = width/2
    imgset.offset_y = height/2
    #observed_xml = imgset.to_xml()
    
    pl.ra_hr = imgset.center_x / 15
    pl.dec_deg = imgset.center_y
    
    pl.foreground_image_set = imgset
    fld.children.append(pl)
    pl.zoom_level = 1

with open('/orange/adamginsburg/web/public/jwst/brick_2221/brick.wtml', 'w') as fh:
    write_xml_doc(fld.to_xml(), dest_stream=fh)

# %%
url = 'https://www.adamgginsburg.com/images/gc/gc_fullres_6_small.jpg'
turl = 'https://www.adamgginsburg.com/images/gc/gc_winner_800x800.jpg'
content = requests.get(url).content
fh = BytesIO(content)
img = Image.open(fh)

tf = tempfile.NamedTemporaryFile()
with open(tf.name, 'wb') as fh_:
    fh_.write(content)
    avm = pyavm.AVM.from_image(tf.name)

ww = avm.to_wcs()
height, width, _ = np.array(img).shape

    
pl = place.Place()
pl.name = 'Galactic Center in the Radio and IR'
if turl:
    pl.thumbnail = turl
pl.constellation = 'SAGITTARIUS'
pl.data_set_type = 'SKY'
pl.opacity = 100

imgset = imageset.ImageSet()
#imgset.set_position_from_wcs(ww.to_header(), width=width, height=height, place=pl, fov_factor=2.5)
cen = ww.pixel_to_world(width/2, height/2)
imgset.center_x = cen.fk5.ra.deg
imgset.center_y = cen.fk5.dec.deg
imgset.projection = 'SKY_IMAGE'
imgset.base_degrees_per_tile = (ww.proj_plane_pixel_area()**0.5).value


imgset.file_type = '.jpg'
imgset.url = url
if turl:
    imgset.thumbnail_url = turl
imgset.bottoms_up = False

offcen = ww.pixel_to_world(width/2, height)
posang = coordinates.position_angle(cen.fk5.ra, cen.fk5.dec, offcen.fk5.ra, offcen.fk5.dec)

imgset.rotation_deg = posang.to(u.deg).value
imgset.band_pass = "RADIO"
imgset.offset_x = width/2
imgset.offset_y = height/2
#observed_xml = imgset.to_xml()

pl.ra_hr = imgset.center_x / 15
pl.dec_deg = imgset.center_y

pl.foreground_image_set = imgset
fld.children.append(pl)
pl.zoom_level = 10
#pl.rotation_deg = posang.to(u.deg).value

with open('/orange/adamginsburg/web/public/jwst/brick_2221/brick_gc.wtml', 'w') as fh:
    write_xml_doc(fld.to_xml(), dest_stream=fh)
print('done')
# Out:
# done

# %%
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 933120000

url = 'https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_TENS_noaxes.png'
imfn = '/orange/adamginsburg/web/public/ACES/MUSTANG_TENS_noaxes.png'
if not os.path.exists(imfn.replace(".png", "_thumbnail.png")):
    img = Image.open(imfn)
    img.thumbnail((100, 100))
    img.save(imfn.replace(".png", "_thumbnail.png"))
turl = 'https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_TENS_noaxes_thumbnail.png'
img = Image.open(imfn)

avm = pyavm.AVM.from_image(imfn)

ww = avm.to_wcs()
height, width, _ = np.array(img).shape

    
pl = place.Place()
pl.name = 'MUSTANG TENS'
if turl:
    pl.thumbnail = turl
pl.constellation = 'SAGITTARIUS'
pl.data_set_type = 'SKY'
pl.opacity = 100

imgset = imageset.ImageSet()
#imgset.set_position_from_wcs(ww.to_header(), width=width, height=height, place=pl, fov_factor=2.5)
cen = ww.pixel_to_world(width/2, height/2)
imgset.center_x = cen.fk5.ra.deg
imgset.center_y = cen.fk5.dec.deg
imgset.projection = 'SKY_IMAGE'
imgset.base_degrees_per_tile = (ww.proj_plane_pixel_area()**0.5).value


print(width, height, imgset.base_degrees_per_tile)
      
imgset.file_type = '.png'
imgset.url = url
if turl:
    imgset.thumbnail_url = turl
imgset.bottoms_up = False

offcen = ww.pixel_to_world(width/2, height)
posang = coordinates.position_angle(cen.fk5.ra, cen.fk5.dec, offcen.fk5.ra, offcen.fk5.dec)

imgset.rotation_deg = posang.to(u.deg).value
imgset.band_pass = "RADIO"
imgset.offset_x = width/2
imgset.offset_y = height/2
#observed_xml = imgset.to_xml()

pl.ra_hr = imgset.center_x / 15
pl.dec_deg = imgset.center_y

pl.foreground_image_set = imgset
fld.children.append(pl)
pl.zoom_level = 10
#pl.rotation_deg = posang.to(u.deg).value

with open('/orange/adamginsburg/web/public/jwst/brick_2221/brick_gc.wtml', 'w') as fh:
    write_xml_doc(fld.to_xml(), dest_stream=fh)
print('done')
# Out:
# 4288 4175 0.0002777777777778001
# done

# %%
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 933120000

url = 'https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_12m_feather_noaxes.png'
imfn = '/orange/adamginsburg/web/public/ACES/MUSTANG_12m_feather_noaxes.png'
if not os.path.exists(imfn.replace(".png", "_thumbnail.png")):
    img = Image.open(imfn)
    img.thumbnail((100, 100))
    img.save(imfn.replace(".png", "_thumbnail.png"))
turl = 'https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_12m_feather_noaxes_thumbnail.png'
img = Image.open(imfn)

avm = pyavm.AVM.from_image(imfn)

ww = avm.to_wcs()
height, width, _ = np.array(img).shape

    
pl = place.Place()
pl.name = 'ACES and TENS (png)'
if turl:
    pl.thumbnail = turl
pl.constellation = 'SAGITTARIUS'
pl.data_set_type = 'SKY'
pl.opacity = 100

imgset = imageset.ImageSet()
#imgset.set_position_from_wcs(ww.to_header(), width=width, height=height, place=pl, fov_factor=2.5)
cen = ww.pixel_to_world(width/2, height/2)
imgset.center_x = cen.fk5.ra.deg
imgset.center_y = cen.fk5.dec.deg
imgset.projection = 'SKY_IMAGE'
imgset.base_degrees_per_tile = (ww.proj_plane_pixel_area()**0.5).value


print(width, height, imgset.base_degrees_per_tile)
      
imgset.file_type = '.png'
imgset.url = url
if turl:
    imgset.thumbnail_url = turl
imgset.bottoms_up = False

offcen = ww.pixel_to_world(width/2, height)
posang = coordinates.position_angle(cen.fk5.ra, cen.fk5.dec, offcen.fk5.ra, offcen.fk5.dec)

imgset.rotation_deg = posang.to(u.deg).value
imgset.band_pass = "RADIO"
imgset.offset_x = width/2
imgset.offset_y = height/2
#observed_xml = imgset.to_xml()

pl.ra_hr = imgset.center_x / 15
pl.dec_deg = imgset.center_y

pl.foreground_image_set = imgset
fld.children.append(pl)
pl.zoom_level = 10
#pl.rotation_deg = posang.to(u.deg).value

with open('/orange/adamginsburg/web/public/jwst/brick_2221/brick_gc.wtml', 'w') as fh:
    write_xml_doc(fld.to_xml(), dest_stream=fh)
print('done')
# Out:
# 18620 10200 5.555555554300004e-05
# done

# %% [raw]
# # TOAST version
# url = 'https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_Feather/{1}/{3}/{3}_{2}.png'
# turl = 'https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_12m_feather_noaxes_thumbnail.png'
#
# avm = pyavm.AVM.from_image(imfn)
#
# ww = avm.to_wcs()
# height, width, _ = np.array(img).shape
#
# pl = place.Place()
# pl.name = 'ACES and TENS'
# if turl:
#     pl.thumbnail = turl
# pl.constellation = 'SAGITTARIUS'
# pl.data_set_type = 'SKY'
# pl.opacity = 100
#
# imgset = imageset.ImageSet()
# #imgset.set_position_from_wcs(ww.to_header(), width=width, height=height, place=pl, fov_factor=2.5)
# cen = ww.pixel_to_world(width/2, height/2)
# imgset.center_x = cen.fk5.ra.deg
# imgset.center_y = cen.fk5.dec.deg
# imgset.projection = 'TOAST'
# imgset.base_tile_level = 0
# imgset.base_degrees_per_tile = 1#(ww.proj_plane_pixel_area()**0.5).value
#
# print(width, height, imgset.base_degrees_per_tile)
#
# imgset.file_type = '.png'
# imgset.url = url
# if turl:
#     imgset.thumbnail_url = turl
# imgset.bottoms_up = False
#
# offcen = ww.pixel_to_world(width/2, height)
# posang = coordinates.position_angle(cen.fk5.ra, cen.fk5.dec, offcen.fk5.ra, offcen.fk5.dec)
#
# imgset.rotation_deg = posang.to(u.deg).value
# imgset.band_pass = "RADIO"
# imgset.offset_x = width/2
# imgset.offset_y = height/2
# #observed_xml = imgset.to_xml()
#
# pl.ra_hr = imgset.center_x / 15
# pl.dec_deg = imgset.center_y
#
# pl.foreground_image_set = imgset
# fld.children.append(pl)
# pl.zoom_level = 10
# #pl.rotation_deg = posang.to(u.deg).value
#
# with open('/orange/adamginsburg/web/public/jwst/brick_2221/brick_gc.wtml', 'w') as fh:
#     write_xml_doc(fld.to_xml(), dest_stream=fh)
# print('done')

# %%
#acestens = place.Place.from_file("/orange/adamginsburg/web/public/ACES/MUSTANG_Feather/index_rel.wtml")
acestens = folder.Folder.from_file("/orange/adamginsburg/web/public/ACES/MUSTANG_Feather/index_rel.wtml")
acestens.children[0].name = 'ACES+TENS (toasty)'
fld.children.extend(acestens.children)
with open('/orange/adamginsburg/web/public/jwst/brick_2221/brick_gc.wtml', 'w') as fh:
    write_xml_doc(fld.to_xml(), dest_stream=fh)

# %%
acestens.children[0].name
# Out:
# 'ACES+TENS (toasty)'

# %% [markdown]
# ## Add MEERKAT

# %%
meerplace = place.Place.from_text("""
  <Place Angle="0" AngularSize="0" DataSetType="Sky" Dec="-29.221836082925606" Magnitude="0" Name="MeerKAT_Galactic_Centre_1284MHz-StokesI_tiled" Opacity="100" RA="17.758054459614392" Rotation="0" ZoomLevel="32.8091977224">
    <ForegroundImageSet>
      <ImageSet BandPass="Visible" BaseDegreesPerTile="5.006229504" BaseTileLevel="0" BottomsUp="False" CenterX="266.366790598" CenterY="-29.2213778092" DataMax="0.7066638163374066" DataMin="-0.00125779378158081" DataSetType="Sky" ElevationModel="False" FileType=".fits" Generic="False" Name="MeerKAT_Galactic_Centre_1284MHz-StokesI_tiled" OffsetX="-0.003513894" OffsetY="-0.000458334" PixelCutHigh="0.004745915678209696" PixelCutLow="-0.0003184565157501922" Projection="Tan" QuadTreeMap="" Rotation="-0" Sparse="True" StockSet="False" TileLevels="6" Url="http://data1.wwtassets.org/packages/2022/01_meerkat_gc/MeerKAT_Galactic_Centre_1284MHz-StokesI_tiled/{1}/{3}/{3}_{2}.fits" WidthFactor="2">
        <ThumbnailUrl />
		<Credits>I. Heywood, SARAO</Credits>
		<CreditsUrl>https://archive-gw-1.kat.ac.za/public/repository/10.48479/fyst-hj47/index.html</CreditsUrl>
      </ImageSet>
    </ForegroundImageSet>
  </Place>
""")
fld.children.append(meerplace)
with open('/orange/adamginsburg/web/public/jwst/brick_2221/brick_gc.wtml', 'w') as fh:
    write_xml_doc(fld.to_xml(), dest_stream=fh)

# %% [markdown]
# ## Verify that the file was written

# %%
cat /orange/adamginsburg/web/public/jwst/brick_2221/brick_gc.wtml
# Out:
# <?xml version='1.0' encoding='UTF-8'?>
# <Folder Browseable="True" Group="Explorer" Name="The Brick" Searchable="True" Thumbnail="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter.png" Type="Sky">
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.712968795984" Magnitude="0" Name="Starry Brick F405+F466" Opacity="100" RA="17.769038618397335" Rotation="0" Thumbnail="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars_thumbnail.png" ZoomLevel="1">
#     <ForegroundImageSet>
#       <ImageSet BandPass="IR" BaseDegreesPerTile="1.74737238791e-05" BaseTileLevel="0" BottomsUp="False" CenterX="266.53557927596" CenterY="-28.712968795984" DataSetType="Sky" ElevationModel="False" FileType=".png" Generic="False" Name="" OffsetX="2862.5" OffsetY="1175" Projection="SkyImage" QuadTreeMap="" Rotation="90" Sparse="True" StockSet="False" TileLevels="0" Url="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars.png" WidthFactor="2">
#         <ThumbnailUrl>http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars_thumbnail.png</ThumbnailUrl>
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.712968795984" Magnitude="0" Name="Starless Brick F405+466" Opacity="100" RA="17.769038618397335" Rotation="0" Thumbnail="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter_thumbnail.png" ZoomLevel="1">
#     <ForegroundImageSet>
#       <ImageSet BandPass="IR" BaseDegreesPerTile="1.74737238791e-05" BaseTileLevel="0" BottomsUp="False" CenterX="266.53557927596" CenterY="-28.712968795984" DataSetType="Sky" ElevationModel="False" FileType=".png" Generic="False" Name="" OffsetX="2862.5" OffsetY="1175" Projection="SkyImage" QuadTreeMap="" Rotation="90" Sparse="True" StockSet="False" TileLevels="0" Url="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter.png" WidthFactor="2">
#         <ThumbnailUrl>http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter_thumbnail.png</ThumbnailUrl>
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.712998625026" Magnitude="0" Name="Brick: JWST and ALMA" Opacity="100" RA="17.769042598724003" Rotation="0" Thumbnail="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickALMAJWST_WhiteHaze_thumbnail.png" ZoomLevel="1">
#     <ForegroundImageSet>
#       <ImageSet BandPass="IR" BaseDegreesPerTile="1.7499992124599925e-05" BaseTileLevel="0" BottomsUp="False" CenterX="266.53563898086" CenterY="-28.712998625026" DataSetType="Sky" ElevationModel="False" FileType=".png" Generic="False" Name="" OffsetX="2841.5" OffsetY="1164.5" Projection="SkyImage" QuadTreeMap="" Rotation="90" Sparse="True" StockSet="False" TileLevels="0" Url="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickALMAJWST_WhiteHaze.png" WidthFactor="2">
#         <ThumbnailUrl>http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickALMAJWST_WhiteHaze_thumbnail.png</ThumbnailUrl>
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.712998625026" Magnitude="0" Name="Brick: Spitzer" Opacity="100" RA="17.769042598724003" Rotation="0" Thumbnail="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickSpitzer_RGB_I421_thumbnail.png" ZoomLevel="1">
#     <ForegroundImageSet>
#       <ImageSet BandPass="IR" BaseDegreesPerTile="6.99999684983997e-05" BaseTileLevel="0" BottomsUp="False" CenterX="266.53563898086" CenterY="-28.712998625026" DataSetType="Sky" ElevationModel="False" FileType=".png" Generic="False" Name="" OffsetX="710" OffsetY="291" Projection="SkyImage" QuadTreeMap="" Rotation="90" Sparse="True" StockSet="False" TileLevels="0" Url="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickSpitzer_RGB_I421.png" WidthFactor="2">
#         <ThumbnailUrl>http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/BrickSpitzer_RGB_I421_thumbnail.png</ThumbnailUrl>
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.588547418103" Magnitude="0" Name="Cloud C: F405N+F466N" Opacity="100" RA="17.772500556992" Rotation="0" Thumbnail="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F405N_rotated_thumbnail.png" ZoomLevel="1">
#     <ForegroundImageSet>
#       <ImageSet BandPass="IR" BaseDegreesPerTile="8.6768754638e-06" BaseTileLevel="0" BottomsUp="False" CenterX="266.58750835488" CenterY="-28.588547418103" DataSetType="Sky" ElevationModel="False" FileType=".png" Generic="False" Name="" OffsetX="3260.5" OffsetY="8288.5" Projection="SkyImage" QuadTreeMap="" Rotation="90" Sparse="True" StockSet="False" TileLevels="0" Url="http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F405N_rotated.png" WidthFactor="2">
#         <ThumbnailUrl>http://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F405N_rotated_thumbnail.png</ThumbnailUrl>
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.55868913694841" Magnitude="0" Name="Galactic Center in the Radio and IR" Opacity="100" RA="17.782546687722196" Rotation="0" Thumbnail="https://www.adamgginsburg.com/images/gc/gc_winner_800x800.jpg" ZoomLevel="10">
#     <ForegroundImageSet>
#       <ImageSet BandPass="Radio" BaseDegreesPerTile="0.00033333333000000004" BaseTileLevel="0" BottomsUp="False" CenterX="266.73820031583296" CenterY="-28.55868913694841" DataSetType="Sky" ElevationModel="False" FileType=".jpg" Generic="False" Name="" OffsetX="3236.5" OffsetY="1647.5" Projection="SkyImage" QuadTreeMap="" Rotation="301.24129981084394" Sparse="True" StockSet="False" TileLevels="0" Url="https://www.adamgginsburg.com/images/gc/gc_fullres_6_small.jpg" WidthFactor="2">
#         <ThumbnailUrl>https://www.adamgginsburg.com/images/gc/gc_winner_800x800.jpg</ThumbnailUrl>
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.540367115513067" Magnitude="0" Name="MUSTANG TENS" Opacity="100" RA="17.77970297472566" Rotation="0" Thumbnail="https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_TENS_noaxes_thumbnail.png" ZoomLevel="10">
#     <ForegroundImageSet>
#       <ImageSet BandPass="Radio" BaseDegreesPerTile="0.0002777777777778001" BaseTileLevel="0" BottomsUp="False" CenterX="266.6955446208849" CenterY="-28.540367115513067" DataSetType="Sky" ElevationModel="False" FileType=".png" Generic="False" Name="" OffsetX="2144" OffsetY="2087.5" Projection="SkyImage" QuadTreeMap="" Rotation="301.26783363565136" Sparse="True" StockSet="False" TileLevels="0" Url="https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_TENS_noaxes.png" WidthFactor="2">
#         <ThumbnailUrl>https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_TENS_noaxes_thumbnail.png</ThumbnailUrl>
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.616257223159362" Magnitude="0" Name="ACES and TENS (png)" Opacity="100" RA="17.777712632377575" Rotation="0" Thumbnail="https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_12m_feather_noaxes_thumbnail.png" ZoomLevel="10">
#     <ForegroundImageSet>
#       <ImageSet BandPass="Radio" BaseDegreesPerTile="5.555555554300004e-05" BaseTileLevel="0" BottomsUp="False" CenterX="266.6656894856636" CenterY="-28.616257223159362" DataSetType="Sky" ElevationModel="False" FileType=".png" Generic="False" Name="" OffsetX="9310" OffsetY="5100" Projection="SkyImage" QuadTreeMap="" Rotation="301.2759373065145" Sparse="True" StockSet="False" TileLevels="0" Url="https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_12m_feather_noaxes.png" WidthFactor="2">
#         <ThumbnailUrl>https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_12m_feather_noaxes_thumbnail.png</ThumbnailUrl>
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" Constellation="SGR" DataSetType="Sky" Dec="-28.616024753843693" Magnitude="0" Name="ACES+TENS (toasty)" Opacity="100" RA="17.777695683895413" Rotation="0" ZoomLevel="5.77999876421921">
#     <ForegroundImageSet>
#       <ImageSet BandPass="Visible" BaseDegreesPerTile="1.8204440552281342" BaseTileLevel="0" BottomsUp="False" CenterX="266.52436696311" CenterY="-28.819803555216" DataSetType="Sky" ElevationModel="False" FileType=".png" Generic="False" Name="Toasty" OffsetX="-0.23839482865618988" OffsetY="0.00019724597516711402" Projection="Tan" QuadTreeMap="" Rotation="-58.656273848511645" Sparse="True" StockSet="False" TileLevels="7" Url="https://data.rc.ufl.edu/pub/adamginsburg/ACES/MUSTANG_Feather/{1}/{3}/{3}_{2}.png" WidthFactor="2">
#         <ThumbnailUrl />
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
#   <Place Angle="0" AngularSize="0" DataSetType="Sky" Dec="-29.221836082925606" Magnitude="0" Name="MeerKAT_Galactic_Centre_1284MHz-StokesI_tiled" Opacity="100" RA="17.758054459614392" Rotation="0" ZoomLevel="32.8091977224">
#     <ForegroundImageSet>
#       <ImageSet BandPass="Visible" BaseDegreesPerTile="5.006229504" BaseTileLevel="0" BottomsUp="False" CenterX="266.366790598" CenterY="-29.2213778092" DataMax="0.7066638163374066" DataMin="-0.00125779378158081" DataSetType="Sky" ElevationModel="False" FileType=".fits" Generic="False" Name="MeerKAT_Galactic_Centre_1284MHz-StokesI_tiled" OffsetX="-0.003513894" OffsetY="-0.000458334" PixelCutHigh="0.004745915678209696" PixelCutLow="-0.0003184565157501922" Projection="Tan" QuadTreeMap="" Rotation="-0" Sparse="True" StockSet="False" TileLevels="6" Url="http://data1.wwtassets.org/packages/2022/01_meerkat_gc/MeerKAT_Galactic_Centre_1284MHz-StokesI_tiled/{1}/{3}/{3}_{2}.fits" WidthFactor="2">
#         <Credits>I. Heywood, SARAO</Credits>
#         <CreditsUrl>https://archive-gw-1.kat.ac.za/public/repository/10.48479/fyst-hj47/index.html</CreditsUrl>
#         <ThumbnailUrl />
#       </ImageSet>
#     </ForegroundImageSet>
#   </Place>
# </Folder>

# %% [markdown]
# https://worldwidetelescope.org/webclient/?wtml=https://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/brick.wtml#/place=Open_Collections.The_Brick.3&imagery=GLIMPSE_360&ra=17.76904&dec=-28.71300&fov=0.10185

# %% [markdown]
# https://worldwidetelescope.org/webclient/?wtml=https://data.rc.ufl.edu/pub/adamginsburg/jwst/brick_2221/brick_gc.wtml#/place=Open_Collections.The_Brick.3&imagery=GLIMPSE_360&ra=17.76904&dec=-28.71300&fov=0.10185

# %% [markdown]
# # Use ACES generalized version

# %%
ls /orange/adamginsburg/web/public/jwst/brick_2221/
# Out:
# BlueStars_on_RGB.png
# BlueStars_on_RGB_stars.png
# BrAExcessStars_on_RGB.png
# brick2.wtml
# BrickALMAJWST_BrownHaze_InsetZooms2.png
# BrickALMAJWST_BrownHaze_InsetZooms.png
# BrickALMAJWST_BrownHaze_InsetZooms_withOBstars.png
# BrickALMAJWST_BrownHaze.png
# BrickALMAJWST_longwave_RGB.png
# BrickALMAJWST_longwave_RGB_unrotated.png
# BrickALMAJWST_PurpleHaze.png
# BrickALMAJWST_WhiteHaze.png
# BrickALMAJWST_WhiteHaze_thumbnail.png
# brick_cloudc_gc.wtml
# brick_gc.wtml
# BrickJWST_1182p2221_212_200_182.png
# BrickJWST_1182p2221_212_200_187.png
# BrickJWST_1182p2221_405_200_182.png
# BrickJWST_1182p2221_405_200_187.png
# BrickJWST_1182p2221_405_356_212.png
# BrickJWST_1182p2221_444_405_356.png
# BrickJWST_1182p2221_444_410_356.png
# BrickJWST_1182p2221_466_444_356.png
# BrickJWST_1182p2221_466_444_356_thumbnail.png
# BrickJWST_1182p2221_466_444_405.png
# BrickJWST_1182p2221_466_444_410.png
# BrickJWST_212-187-182_RGB_unrotated.png
# BrickJWST_ContSub_LongWave.png
# BrickJWSTLong_InsetZooms2.png
# BrickJWSTLong_InsetZooms3.png
# BrickJWSTLong_InsetZooms4_purplestars.png
# BrickJWSTLong_InsetZooms_NoStars.png
# BrickJWSTLong_InsetZooms_withOBstars.png
# BrickJWST_longwave_RGB_contsubbed.png
# BrickJWST_longwave_RGB.png
# BrickJWST_longwave_RGB_unrotated.png
# BrickJWST_merged_longwave_narrowband_flipped.png
# BrickJWST_merged_longwave_narrowband_lighter.png
# BrickJWST_merged_longwave_narrowband_lighter_thumbnail.png
# BrickJWST_merged_longwave_narrowband.png
# BrickJWST_merged_longwave_narrowband_rotated_lighter_only405.png
# BrickJWST_merged_longwave_narrowband_rotated_lighter_only466.png
# BrickJWST_merged_longwave_narrowband_rotated_lighter.png
# BrickJWST_merged_longwave_narrowband_rotated_lighter_withBrickLineSurveyPointing.png
# BrickJWST_merged_longwave_narrowband_rotated_only405plus466.png
# BrickJWST_merged_longwave_narrowband_rotated_only405.png
# BrickJWST_merged_longwave_narrowband_rotated_only466.png
# BrickJWST_merged_longwave_narrowband_rotated.png
# BrickJWST_merged_longwave_narrowband_rotated_withstars.png
# BrickJWST_merged_longwave_narrowband_unrotated_nogreen.png
# BrickJWST_merged_longwave_narrowband_unrotated.png
# BrickJWST_merged_longwave_narrowband_withstars.png
# BrickJWST_merged_longwave_narrowband_withstars_thumbnail.png
# BrickJWST_merged_longwave_narrowband_withstars_thumbnail_thumbnail.png
# BrickJWST_merged_PaABrA466_narrowband_rotated.png
# BrickJWST_nrgca_longwave_stars_bra_410.png
# BrickJWST_RGB_405_466_410.png
# BrickJWST_RGB_466_212_182.png
# BrickJWST_shortwave_RGB_187_212_182.png
# BrickSpitzer_RGB_I321.png
# BrickSpitzer_RGB_I421.png
# BrickSpitzer_RGB_I421_thumbnail.png
# BrickSpitzer_RGB_I431.png
# BrickSpitzer_RGB_I432.png
# BrickSpitzer_RGB_M1I42.png
# brick.wtml
# cloudc@
# old_images/
# Spitzer_InsetZooms2.png
# Spitzer_InsetZooms_3.png
# Spitzer_InsetZooms_icecoloredinsets.png
# Spitzer_RGB_I321.png
# Spitzer_RGB_I421.png
# Spitzer_RGB_I431.png
# Spitzer_RGB_I432.png
# Spitzer_RGB_M1I42.png
# toasts/
# WhiteHaze.png

# %%
avm.to_wcs()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN' 'DEC--TAN'
# CRVAL : 266.5356389808593 -28.712998625026
# CRPIX : 2829.531214097682 1167.45507920672
# NAXIS : 0  0

# %%
import pyavm
for fn in glob.glob("/orange/adamginsburg/web/public/jwst/brick_2221/*png"):
    try:
        avm = pyavm.AVM.from_image(fn)
        avm.to_wcs()
        print(fn, 'success')
    except Exception as ex:
        print(fn, ex)
# Out:
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_356.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars_thumbnail.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I421_thumbnail.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_withstars.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms2.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BlueStars_on_RGB.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars_thumbnail_thumbnail.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_shortwave_RGB_187_212_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I421.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405plus466.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I432.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I431.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_405_356.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_ContSub_LongWave.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_WhiteHaze.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only405.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_410_356.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_405.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms2.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I321.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_466_212_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_nrgca_longwave_stars_bra_410.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_PaABrA466_narrowband_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_356_212.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms_withOBstars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_187.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms2.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_410.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter_thumbnail.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I431.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms4_purplestars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only466.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I321.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms_withOBstars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrAExcessStars_on_RGB.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_PurpleHaze.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I432.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I421.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_212-187-182_RGB_unrotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_withBrickLineSurveyPointing.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms3.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_M1I42.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_356_thumbnail.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BlueStars_on_RGB_stars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_M1I42.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_flipped.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms_NoStars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_unrotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_187.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms_3.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_WhiteHaze_thumbnail.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms_icecoloredinsets.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated_nogreen.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB_unrotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only466.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_405_466_410.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_contsubbed.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/WhiteHaze.png No XMP packet present in file

# %%
ls /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_212-187-182_RGB_unrotated.png
# Out:
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_212-187-182_RGB_unrotated.png

# %%
ls -lh /orange/adamginsburg/jwst/brick/analysis/toast_brick.py
# Out:
# -rw-r--r-- 1 adamginsburg adamginsburg 8.6K May 10 11:05 /orange/adamginsburg/jwst/brick/analysis/toast_brick.py

# %% [markdown]
# ## orientations are wrong

# %%
# %run /orange/adamginsburg/jwst/brick/analysis/toast_brick.py
# Out:
# Making no-toast index
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_356.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_withstars.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms2.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BlueStars_on_RGB.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_shortwave_RGB_187_212_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I421.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405plus466.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I432.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I431.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_405_356.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_ContSub_LongWave.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_200_182_115.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_WhiteHaze.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only405.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_410_356.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_405.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_187_115.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms2.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_356_212_200.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I321.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_466_212_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_nrgca_longwave_stars_bra_410.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_PaABrA466_narrowband_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_356_200.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_356_212.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms_withOBstars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_187.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms2.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_410.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I431.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms4_purplestars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_410_356_212.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only466.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I321.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms_withOBstars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_182_115.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrAExcessStars_on_RGB.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_PurpleHaze.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I432.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I421.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_212-187-182_RGB_unrotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_withBrickLineSurveyPointing.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms3.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_M1I42.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BlueStars_on_RGB_stars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_M1I42.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_flipped.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms_NoStars.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_410_200_182.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_unrotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_200_187_115.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_187.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms_3.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms_icecoloredinsets.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated_nogreen.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB_unrotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only466.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_405_466_410.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_contsubbed.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/WhiteHaze.png No XMP packet present in file
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F182M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F182M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F182M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F410M_B-F182M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F410M_B-F405N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F405N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F405N_B-F212N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F182M_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F212N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_G-F182M_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F212N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcSpitzer_R-I4_G-I3_B-I2.png success
# WCS coordinates must be in an equatorial/TAN projection
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_G-F212N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F405N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F410M_B-F405N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F405N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F410M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F182M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F212N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F212N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F212N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_longwave_narrowband_rotated_withstars.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F410M_B-F182M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F182M_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F212N_B-F182M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F410M_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F187N_rotated.png success
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_B-F182M_rotated.png success
# Making all indexes
# imlist is ['/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_200_187_115_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_356.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only466_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I321_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I421_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_withstars.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_410_356_212_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms2.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BlueStars_on_RGB.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars_thumbnail_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_shortwave_RGB_187_212_182.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_187_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I421.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_410_200_182_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405plus466.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_182.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I432.png', '/orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I431.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_405_356.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_ContSub_LongWave.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_200_182_115.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_WhiteHaze.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_405_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only466_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only405.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_410_356.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_405.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_187_115.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_356_200_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms2.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_187_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_contsubbed_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_356_212_200.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I321.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_182_115_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_466_212_182.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_356_212_200_thumbnail.png', '/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_nrgca_longwave_stars_bra_410.png ...
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_200_187_115_thumbnail.png BrickJWST_1182p2221_200_187_115_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_356.png BrickJWST_1182p2221_466_444_356
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_466_444_356/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only466_thumbnail.png BrickJWST_merged_longwave_narrowband_rotated_lighter_only466_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I321_thumbnail.png BrickSpitzer_RGB_I321_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars_thumbnail.png BrickJWST_merged_longwave_narrowband_withstars_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I421_thumbnail.png BrickSpitzer_RGB_I421_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_withstars.png BrickJWST_merged_longwave_narrowband_rotated_withstars
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_withstars/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_410_356_212_thumbnail.png BrickJWST_1182p2221_410_356_212_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms2.png BrickJWSTLong_InsetZooms2
# /orange/adamginsburg/web/public/jwst/brick_2221/BlueStars_on_RGB.png BlueStars_on_RGB
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze.png BrickALMAJWST_BrownHaze
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_BrownHaze/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars_thumbnail_thumbnail.png BrickJWST_merged_longwave_narrowband_withstars_thumbnail_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_shortwave_RGB_187_212_182.png BrickJWST_shortwave_RGB_187_212_182
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_shortwave_RGB_187_212_182/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_187_thumbnail.png BrickJWST_1182p2221_212_200_187_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I421.png Spitzer_RGB_I421
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_410_200_182_thumbnail.png BrickJWST_1182p2221_410_200_182_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405plus466.png BrickJWST_merged_longwave_narrowband_rotated_only405plus466
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_only405plus466/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_182.png BrickJWST_1182p2221_405_200_182
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_405_200_182/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I432.png BrickSpitzer_RGB_I432
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_I432/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I431.png Spitzer_RGB_I431
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_405_356.png BrickJWST_1182p2221_444_405_356
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_444_405_356/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_ContSub_LongWave.png BrickJWST_ContSub_LongWave
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_ContSub_LongWave/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_200_182_115.png BrickJWST_1182p2221_200_182_115
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_200_182_115/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_WhiteHaze.png BrickALMAJWST_WhiteHaze
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_WhiteHaze/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_405_thumbnail.png BrickJWST_1182p2221_466_444_405_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only466_thumbnail.png BrickJWST_merged_longwave_narrowband_rotated_only466_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only405.png BrickJWST_merged_longwave_narrowband_rotated_lighter_only405
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_lighter_only405/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_410_356.png BrickJWST_1182p2221_444_410_356
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_444_410_356/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_405.png BrickJWST_1182p2221_466_444_405
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_466_444_405/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_187_115.png BrickJWST_1182p2221_212_187_115
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_212_187_115/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB_thumbnail.png BrickALMAJWST_longwave_RGB_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_356_200_thumbnail.png BrickJWST_1182p2221_405_356_200_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms2.png BrickALMAJWST_BrownHaze_InsetZooms2
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_187_thumbnail.png BrickJWST_1182p2221_405_200_187_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_contsubbed_thumbnail.png BrickJWST_longwave_RGB_contsubbed_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_356_212_200.png BrickJWST_1182p2221_356_212_200
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_356_212_200/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_thumbnail.png BrickALMAJWST_BrownHaze_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I321.png BrickSpitzer_RGB_I321
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_I321/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated.png BrickJWST_merged_longwave_narrowband_unrotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_unrotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_182_115_thumbnail.png BrickJWST_1182p2221_212_182_115_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_466_212_182.png BrickJWST_RGB_466_212_182
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_RGB_466_212_182/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_356_212_200_thumbnail.png BrickJWST_1182p2221_356_212_200_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_nrgca_longwave_stars_bra_410.png BrickJWST_nrgca_longwave_stars_bra_410
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_nrgca_longwave_stars_bra_410/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I431_thumbnail.png BrickSpitzer_RGB_I431_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_PaABrA466_narrowband_rotated.png BrickJWST_merged_PaABrA466_narrowband_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_PaABrA466_narrowband_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_356_200.png BrickJWST_1182p2221_405_356_200
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_405_356_200/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_356_212.png BrickJWST_1182p2221_405_356_212
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_405_356_212/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_356_212_thumbnail.png BrickJWST_1182p2221_405_356_212_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_thumbnail.png BrickJWST_merged_longwave_narrowband_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms_withOBstars.png BrickALMAJWST_BrownHaze_InsetZooms_withOBstars
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_187.png BrickJWST_1182p2221_405_200_187
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_405_200_187/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405_thumbnail.png BrickJWST_merged_longwave_narrowband_rotated_only405_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms2.png Spitzer_InsetZooms2
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_nrgca_longwave_stars_bra_410_thumbnail.png BrickJWST_nrgca_longwave_stars_bra_410_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_flipped_thumbnail.png BrickJWST_merged_longwave_narrowband_flipped_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I432_thumbnail.png BrickSpitzer_RGB_I432_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_182_thumbnail.png BrickJWST_1182p2221_212_200_182_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_410.png BrickJWST_1182p2221_466_444_410
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_466_444_410/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter_thumbnail.png BrickJWST_merged_longwave_narrowband_lighter_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405plus466_thumbnail.png BrickJWST_merged_longwave_narrowband_rotated_only405plus466_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I431.png BrickSpitzer_RGB_I431
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_I431/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB.png BrickALMAJWST_longwave_RGB
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_longwave_RGB/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms4_purplestars.png BrickJWSTLong_InsetZooms4_purplestars
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_410_356_212.png BrickJWST_1182p2221_410_356_212
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_410_356_212/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only466.png BrickJWST_merged_longwave_narrowband_rotated_only466
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_only466/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I321.png Spitzer_RGB_I321
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_withstars.png BrickJWST_merged_longwave_narrowband_withstars
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_withstars/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_lighter.png BrickJWST_merged_longwave_narrowband_lighter
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_lighter/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_BrownHaze_InsetZooms.png BrickALMAJWST_BrownHaze_InsetZooms
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms_withOBstars.png BrickJWSTLong_InsetZooms_withOBstars
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_182_115.png BrickJWST_1182p2221_212_182_115
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_212_182_115/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrAExcessStars_on_RGB.png BrAExcessStars_on_RGB
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_187_115_thumbnail.png BrickJWST_1182p2221_212_187_115_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_PurpleHaze.png BrickALMAJWST_PurpleHaze
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_PurpleHaze/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_I432.png Spitzer_RGB_I432
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_I421.png BrickSpitzer_RGB_I421
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_I421/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter.png BrickJWST_merged_longwave_narrowband_rotated_lighter
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_lighter/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB.png BrickJWST_longwave_RGB
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_longwave_RGB/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_212-187-182_RGB_unrotated.png BrickJWST_212-187-182_RGB_unrotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_212-187-182_RGB_unrotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_only405.png BrickJWST_merged_longwave_narrowband_rotated_only405
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_only405/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_withBrickLineSurveyPointing.png BrickJWST_merged_longwave_narrowband_rotated_lighter_withBrickLineSurveyPointing
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_410_thumbnail.png BrickJWST_1182p2221_466_444_410_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms3.png BrickJWSTLong_InsetZooms3
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_shortwave_RGB_187_212_182_thumbnail.png BrickJWST_shortwave_RGB_187_212_182_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_M1I42.png BrickSpitzer_RGB_M1I42
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_M1I42/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_466_444_356_thumbnail.png BrickJWST_1182p2221_466_444_356_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB_unrotated_thumbnail.png BrickALMAJWST_longwave_RGB_unrotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BlueStars_on_RGB_stars.png BlueStars_on_RGB_stars
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated.png BrickJWST_merged_longwave_narrowband_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_212-187-182_RGB_unrotated_thumbnail.png BrickJWST_212-187-182_RGB_unrotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_182.png BrickJWST_1182p2221_212_200_182
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_212_200_182/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_RGB_M1I42.png Spitzer_RGB_M1I42
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only405_thumbnail.png BrickJWST_merged_longwave_narrowband_rotated_lighter_only405_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_withstars_thumbnail.png BrickJWST_merged_longwave_narrowband_rotated_withstars_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_thumbnail.png BrickJWST_merged_longwave_narrowband_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_flipped.png BrickJWST_merged_longwave_narrowband_flipped
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_flipped/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWSTLong_InsetZooms_NoStars.png BrickJWSTLong_InsetZooms_NoStars
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_410_200_182.png BrickJWST_1182p2221_410_200_182
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_410_200_182/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_PaABrA466_narrowband_rotated_thumbnail.png BrickJWST_merged_PaABrA466_narrowband_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_unrotated_thumbnail.png BrickJWST_longwave_RGB_unrotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_thumbnail.png BrickJWST_longwave_RGB_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_410_356_thumbnail.png BrickJWST_1182p2221_444_410_356_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickSpitzer_RGB_M1I42_thumbnail.png BrickSpitzer_RGB_M1I42_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated_nogreen_thumbnail.png BrickJWST_merged_longwave_narrowband_unrotated_nogreen_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_ContSub_LongWave_thumbnail.png BrickJWST_ContSub_LongWave_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_unrotated.png BrickJWST_longwave_RGB_unrotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_longwave_RGB_unrotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_405_200_182_thumbnail.png BrickJWST_1182p2221_405_200_182_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_200_187_115.png BrickJWST_1182p2221_200_187_115
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_200_187_115/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_PurpleHaze_thumbnail.png BrickALMAJWST_PurpleHaze_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_212_200_187.png BrickJWST_1182p2221_212_200_187
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_212_200_187/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms_3.png Spitzer_InsetZooms_3
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_466_212_182_thumbnail.png BrickJWST_RGB_466_212_182_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_WhiteHaze_thumbnail.png BrickALMAJWST_WhiteHaze_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_200_182_115_thumbnail.png BrickJWST_1182p2221_200_182_115_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband.png BrickJWST_merged_longwave_narrowband
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/Spitzer_InsetZooms_icecoloredinsets.png Spitzer_InsetZooms_icecoloredinsets
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated_nogreen.png BrickJWST_merged_longwave_narrowband_unrotated_nogreen
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_unrotated_nogreen/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickALMAJWST_longwave_RGB_unrotated.png BrickALMAJWST_longwave_RGB_unrotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_longwave_RGB_unrotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_1182p2221_444_405_356_thumbnail.png BrickJWST_1182p2221_444_405_356_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_thumbnail.png BrickJWST_merged_longwave_narrowband_rotated_lighter_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_unrotated_thumbnail.png BrickJWST_merged_longwave_narrowband_unrotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_405_466_410_thumbnail.png BrickJWST_RGB_405_466_410_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_merged_longwave_narrowband_rotated_lighter_only466.png BrickJWST_merged_longwave_narrowband_rotated_lighter_only466
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_lighter_only466/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_RGB_405_466_410.png BrickJWST_RGB_405_466_410
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_RGB_405_466_410/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_longwave_RGB_contsubbed.png BrickJWST_longwave_RGB_contsubbed
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_longwave_RGB_contsubbed/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/WhiteHaze.png WhiteHaze
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated_thumbnail.png cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F187N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F187N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F405N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F182M_rotated.png cloudcJWST_merged-reproject_R-F466N_B-F182M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F466N_B-F182M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_G-F182M_B-F187N_rotated_thumbnail.png cloudcJWST_merged_R-F212N_G-F182M_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F182M_rotated.png cloudcJWST_merged-reproject_R-F405N_B-F182M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F405N_B-F182M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F182M_rotated.png cloudcJWST_merged_R-F466N_B-F182M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_B-F182M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F410M_B-F405N_rotated_thumbnail.png cloudcJWST_merged_R-F410M_B-F405N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F187N_rotated.png cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F410M_B-F182M_rotated.png cloudcJWST_merged-reproject_R-F410M_B-F182M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F410M_B-F182M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F410M_B-F405N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F410M_B-F405N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F410M_B-F405N_rotated.png cloudcJWST_merged_R-F410M_B-F405N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F410M_B-F405N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F212N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F212N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F212N_B-F182M_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F212N_B-F182M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F405N_rotated.png cloudcJWST_merged-reproject_R-F466N_B-F405N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F466N_B-F405N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F405N_B-F212N_rotated.png cloudcJWST_merged_R-F466N_G-F405N_B-F212N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_G-F405N_B-F212N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F182M_B-F187N_rotated.png cloudcJWST_merged-reproject_R-F182M_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F182M_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F212N_B-F187N_rotated.png cloudcJWST_merged_R-F466N_G-F212N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_G-F212N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F410M_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F466N_B-F410M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F212N_rotated_thumbnail.png cloudcJWST_merged_R-F405N_B-F212N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_G-F182M_B-F187N_rotated.png cloudcJWST_merged_R-F212N_G-F182M_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F212N_G-F182M_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F405N_B-F187N_rotated_thumbnail.png cloudcJWST_merged_R-F466N_G-F405N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F212N_rotated.png cloudcJWST_merged-reproject_R-F405N_B-F212N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F405N_B-F212N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcSpitzer_R-I4_G-I3_B-I2.png cloudcSpitzer_R-I4_G-I3_B-I2
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcSpitzer_R-I4_G-I3_B-I2.png failed
# `x0` is infeasible.
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F187N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F466N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated.png cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F212N_B-F187N_rotated_thumbnail.png cloudcJWST_merged_R-F466N_G-F212N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_G-F212N_B-F187N_rotated.png cloudcJWST_merged_R-F405N_G-F212N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F405N_G-F212N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F182M_B-F187N_rotated_thumbnail.png cloudcJWST_merged_R-F182M_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F410M_B-F182M_rotated_thumbnail.png cloudcJWST_merged_R-F410M_B-F182M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F405N_B-F187N_rotated.png cloudcJWST_merged_R-F466N_G-F405N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_G-F405N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F187N_rotated.png cloudcJWST_merged_R-F466N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F410M_B-F405N_rotated.png cloudcJWST_merged-reproject_R-F410M_B-F405N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F410M_B-F405N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F212N_B-F187N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F212N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F187N_rotated.png cloudcJWST_merged-reproject_R-F405N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F405N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F187N_rotated.png cloudcJWST_merged_R-F405N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F405N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F405N_rotated.png cloudcJWST_merged_R-F466N_B-F405N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_B-F405N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F410M_rotated.png cloudcJWST_merged-reproject_R-F466N_B-F410M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F466N_B-F410M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F182M_rotated.png cloudcJWST_merged_R-F405N_B-F182M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F405N_B-F182M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F212N_rotated.png cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F212N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F466N_G-F405N_B-F212N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_longwave_narrowband_rotated_withstars_thumbnail.png cloudcJWST_merged_longwave_narrowband_rotated_withstars_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F187N_rotated_thumbnail.png cloudcJWST_merged_R-F466N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_B-F187N_rotated.png cloudcJWST_merged_R-F212N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F212N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F405N_rotated_thumbnail.png cloudcJWST_merged_R-F466N_B-F405N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F187N_rotated_thumbnail.png cloudcJWST_merged_R-F405N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F405N_B-F212N_rotated_thumbnail.png cloudcJWST_merged_R-F466N_G-F405N_B-F212N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F212N_rotated.png cloudcJWST_merged_R-F405N_B-F212N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F405N_B-F212N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F212N_B-F187N_rotated.png cloudcJWST_merged-reproject_R-F212N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F212N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F182M_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F466N_B-F182M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_G-F212N_B-F187N_rotated_thumbnail.png cloudcJWST_merged_R-F405N_G-F212N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F405N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F466N_B-F405N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_longwave_narrowband_rotated_withstars.png cloudcJWST_merged_longwave_narrowband_rotated_withstars
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_longwave_narrowband_rotated_withstars/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F410M_B-F182M_rotated.png cloudcJWST_merged_R-F410M_B-F182M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F410M_B-F182M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F182M_B-F187N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F182M_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F410M_rotated_thumbnail.png cloudcJWST_merged_R-F466N_B-F410M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F182M_B-F187N_rotated.png cloudcJWST_merged_R-F182M_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F182M_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_B-F187N_rotated_thumbnail.png cloudcJWST_merged_R-F212N_B-F187N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F212N_B-F182M_rotated.png cloudcJWST_merged-reproject_R-F212N_B-F182M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F212N_B-F182M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F410M_rotated.png cloudcJWST_merged_R-F466N_B-F410M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_B-F410M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_B-F182M_rotated_thumbnail.png cloudcJWST_merged_R-F212N_B-F182M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F212N_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F405N_B-F212N_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F405N_B-F182M_rotated_thumbnail.png cloudcJWST_merged_R-F405N_B-F182M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcSpitzer_R-I4_G-I3_B-I2_thumbnail.png cloudcSpitzer_R-I4_G-I3_B-I2_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F405N_B-F182M_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F405N_B-F182M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F466N_B-F187N_rotated.png cloudcJWST_merged-reproject_R-F466N_B-F187N_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged-reproject_R-F466N_B-F187N_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F212N_B-F182M_rotated.png cloudcJWST_merged_R-F212N_B-F182M_rotated
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F212N_B-F182M_rotated/index.wtml
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged-reproject_R-F410M_B-F182M_rotated_thumbnail.png cloudcJWST_merged-reproject_R-F410M_B-F182M_rotated_thumbnail
# /orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_B-F182M_rotated_thumbnail.png cloudcJWST_merged_R-F466N_B-F182M_rotated_thumbnail
# ['/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_466_444_356/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_withstars/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_BrownHaze/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_shortwave_RGB_187_212_182/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_only405plus466/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_405_200_182/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_I432/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_444_405_356/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_ContSub_LongWave/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_200_182_115/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_WhiteHaze/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_lighter_only405/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_444_410_356/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_466_444_405/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_212_187_115/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_356_212_200/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_I321/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_unrotated/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_RGB_466_212_182/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_nrgca_longwave_stars_bra_410/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_PaABrA466_narrowband_rotated/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_405_356_200/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_405_356_212/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_405_200_187/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_466_444_410/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_I431/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_longwave_RGB/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_410_356_212/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_only466/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_withstars/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_lighter/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_1182p2221_212_182_115/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickALMAJWST_PurpleHaze/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickSpitzer_RGB_I421/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_lighter/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_longwave_RGB/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_212-187-182_RGB_unrotated/index.wtml', '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_merged_longwave_narrowband_rotated_only405/index.wtml', '/orange/adamginsburg/web/public/j ...
# Making joint indexes
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /blue/adamginsburg/adamginsburg/jwst/brick/analysis/toast_brick.py:261
#     259 if __name__ == "__main__":
#     260     main()
# --> 261     make_joint_index(indexes)
#     264 if __name__ == "__main__":
#     265     main()
#
# NameError: name 'indexes' is not defined

# %%
toast('/orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated.png',
      targetdir='/orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated/'
     )
# Out:
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated/index.wtml
# '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcJWST_merged_R-F466N_G-F410M_B-F405N_rotated/index.wtml'

# %%
toast('/orange/adamginsburg/jwst/brick/images/BrickJWST_212-187-182_RGB_unrotated.png',
      targetdir='/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_212-187-182_RGB_unrotated'
     )
# Out:
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_212-187-182_RGB_unrotated/index.wtml
# '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_212-187-182_RGB_unrotated/index.wtml'

# %%
toast('/orange/adamginsburg/web/public/jwst/brick_2221/BrickJWST_212-187-182_RGB_unrotated.png',
      targetdir='/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_212-187-182_RGB_unrotated'
     )
# Out:
# Wrote  /orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_212-187-182_RGB_unrotated/index.wtml
# '/orange/adamginsburg/web/public/jwst/brick_2221/toasts/BrickJWST_212-187-182_RGB_unrotated/index.wtml'

# %% [raw]
# toast('/orange/adamginsburg/web/public/jwst/brick_2221/cloudc/cloudcSpitzer_R-I4_G-I3_B-I2.png',
#       targetdir='/orange/adamginsburg/web/public/jwst/brick_2221/toasts/cloudcSpitzer_R-I4_G-I3_B-I2')
